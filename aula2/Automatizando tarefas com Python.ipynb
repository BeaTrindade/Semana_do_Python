# %% [markdown]
# # Problema
#
# - Passo 1: buscar dados dos valores das ações de forma automática no site do Yahoo Finanças
# - Paaso 2: gerar as análises solicitadas pelo gestor de forma automática
# - passo3: enviar um email automaticamente para o gestor com os resultados das análises

# %% [markdown]
# # Passo 1

# %%
# !pip install yfinance

# %%
import yfinance

# %% [markdown]
# - dados[Variavel] ticker[variavel]
# - yfinance.Ticker("CSNA3.SA")[nome da empresa no yahho]
# - yfinance.Ticker(ticker) [com variavel para a pessoa escolher]
# - .history("6mo")[mo = mes d = dias]

# %%
ticker = input("Digite a sigla da ação desejada")
dados = yfinance.Ticker(ticker).history("6mo")
fechamento = dados.Close
fechamento.plot()
# Out:
# Digite a sigla da ação desejadaCSNA3.SA
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Pass 2
# Análises dos últimos 6 meses:
#
# - Cotação máxima
# - Cotação minima
# - Cotação atual

# %% [markdown]
# - fechamento.min() [Minimo da tablea]
# - fechamento.max() [maximo da tabela]
# - fechamento[-1] Dentro do Colchetes usra de 0 até ... ou -1 até ..., para buscar as linhas.

# %%
maxima = fechamento.max()
minima = fechamento.min()
atual = fechamento[-1]

fechamento
# Out:
# Date
# 2022-06-09 00:00:00-03:00    18.094624
# 2022-06-10 00:00:00-03:00    18.085411
# 2022-06-13 00:00:00-03:00    16.989048
# 2022-06-14 00:00:00-03:00    16.703438
# 2022-06-15 00:00:00-03:00    16.528389
#                                ...
# 2022-12-05 00:00:00-03:00    14.530000
# 2022-12-06 00:00:00-03:00    14.700000
# 2022-12-07 00:00:00-03:00    14.420000
# 2022-12-08 00:00:00-03:00    14.080000
# 2022-12-09 00:00:00-03:00    14.490000
# Name: Close, Length: 127, dtype: float64

# %%
minima
# Out:
# 11.092631340026855

# %%
maxima
# Out:
# 18.094623565673828

# %%
atual
# Out:
# 14.489999771118164

# %% [markdown]
# # Passo 3
#
# - abrir uma nova aba e digitar o endereço do gmail
# - clicar no botão Escrever
# - preeencher o email do destinatario
# - preencher o assunto
# - escrever o e-mail
# - clicar em enviar
#
#
# - pyautogui (Executa o teclado)
# - pyperclip (Texto)
# - pyautogui.PAUSE (Tempo de espera)

# %%
# !pip install pyautogui
# Out:
# ...
#      ---------------------------------------- 59.0/59.0 kB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
# !pip install pyperclip

# %%
import pyautogui
import pyperclip

# %%
pyautogui.PAUSE = 2
pyautogui.hotkey("ctrl","t")
pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("enter")
pyautogui.click(x=68, y=171)

pyperclip.copy("gestor@gmail.com")
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("tab")
                 
pyperclip.copy("Análises diárias")
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("tab")

mensagem = f"""
Prezado Gestor,
Thiago Rocha Silva
Seguem as análises dos últimos seis meses da ação {ticker}:

Cotação máxima: R$ {round(maxima, 2)}
Cotação Minima: R$ {round(minima, 2)}
Cotação Atual: R$ {round(atual, 2)}

Qualquer dúvida, estou à disposição:
Att,
Beatriz.
"""
pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl","v")
                 
pyautogui.click(x=375, y=1011)

# %%
import time

time.sleep(10)
pyautogui.position()
# Out:
# Point(x=861, y=720)
